# %% [markdown]
# # Chapter 5 — Live Demos
#
# Three demos to accompany the Chapter 5 slides.
# Based on the [companion notebook](https://github.com/DrEntropy/deep-learning-with-python-notebooks) for *Deep Learning with Python, 3rd Edition*.

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

import numpy as np
import matplotlib.pyplot as plt
import keras
from keras import layers

# %% [markdown]
# ---
# ## Demo 1 — Noise channels on MNIST
#
# Adding 784 random-noise channels doubles the input size.
# The model *should* ignore them — but it can't.

# %%
from keras.datasets import mnist

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28)).astype("float32") / 255

train_images_with_noise = np.concatenate(
    [train_images, np.random.random((len(train_images), 784))], axis=1
)
train_images_with_zeros = np.concatenate(
    [train_images, np.zeros((len(train_images), 784))], axis=1
)

# %%
def get_mnist_model():
    model = keras.Sequential([
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ])
    model.compile(optimizer="adam",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

model = get_mnist_model()
history_noise = model.fit(
    train_images_with_noise, train_labels,
    epochs=10, batch_size=128, validation_split=0.2)

model = get_mnist_model()
history_zeros = model.fit(
    train_images_with_zeros, train_labels,
    epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8686 - loss: 0.4350 - val_accuracy: 0.9237 - val_loss: 0.2673
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9329 - loss: 0.2304 - val_accuracy: 0.9353 - val_loss: 0.2159
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9520 - loss: 0.1605 - val_accuracy: 0.9484 - val_loss: 0.1764
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9671 - loss: 0.1116 - val_accuracy: 0.9536 - val_loss: 0.1592
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9769 - loss: 0.0808 - val_accuracy: 0.9565 - val_loss: 0.1410
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9834 - loss: 0.0579 - val_accuracy: 0.9603 - val_loss: 0.1330
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9888 - loss: 0.0405 - val_accuracy: 0.9628 - val_loss: 0.1294
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9936 - loss: 0.0265 - val_accuracy: 0.9629 - val_loss: 0.1355
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9954 - loss: 0.0195 - val_accuracy: 0.9604 - val_loss: 0.1420
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9972 - loss: 0.0135 - val_accuracy: 0.9580 - val_loss: 0.1634
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9162 - loss: 0.2974 - val_accuracy: 0.9569 - val_loss: 0.1548
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9641 - loss: 0.1248 - val_accuracy: 0.9678 - val_loss: 0.1086
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9752 - loss: 0.0825 - val_accuracy: 0.9707 - val_loss: 0.0930
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9827 - loss: 0.0582 - val_accuracy: 0.9733 - val_loss: 0.0873
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9872 - loss: 0.0442 - val_accuracy: 0.9753 - val_loss: 0.0783
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0320 - val_accuracy: 0.9745 - val_loss: 0.0851
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9931 - loss: 0.0243 - val_accuracy: 0.9785 - val_loss: 0.0762
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9957 - loss: 0.0182 - val_accuracy: 0.9785 - val_loss: 0.0743
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9963 - loss: 0.0150 - val_accuracy: 0.9796 - val_loss: 0.0755
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9976 - loss: 0.0110 - val_accuracy: 0.9792 - val_loss: 0.0740

# %%
epochs = range(1, 11)
plt.plot(epochs, history_noise.history["val_accuracy"], "b-",
         label="With noise channels")
plt.plot(epochs, history_zeros.history["val_accuracy"], "r--",
         label="With zeros channels (control)")
plt.title("Effect of noise channels on validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Validation accuracy")
plt.xticks(epochs)
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## Demo 2 — Model size and overfitting (IMDB)
#
# Train a baseline model and a much larger model on IMDB sentiment classification.
# The bigger model overfits dramatically.

# %%
from keras.datasets import imdb

(train_data, train_labels), _ = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.0
    return results

train_data = vectorize_sequences(train_data)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /Users/ronaldlegere/Documents/dataSciDev/deep-learning-with-python-notebooks/.venv/lib/python3.12/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)

# %%
# Baseline: 16-unit layers
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid"),
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
history_original = model.fit(
    train_data, train_labels,
    epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7774 - loss: 0.5364 - val_accuracy: 0.8552 - val_loss: 0.4112
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8896 - loss: 0.3336 - val_accuracy: 0.8845 - val_loss: 0.3146
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9120 - loss: 0.2517 - val_accuracy: 0.8869 - val_loss: 0.2900
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9289 - loss: 0.2061 - val_accuracy: 0.8910 - val_loss: 0.2742
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9429 - loss: 0.1703 - val_accuracy: 0.8853 - val_loss: 0.2864
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9525 - loss: 0.1433 - val_accuracy: 0.8878 - val_loss: 0.2856
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9581 - loss: 0.1261 - val_accuracy: 0.8815 - val_loss: 0.3086
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9659 - loss: 0.1071 - val_accuracy: 0.8854 - val_loss: 0.3097
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9714 - loss: 0.0943 - val_accuracy: 0.8846 - val_loss: 0.3259
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.0821 - val_accuracy: 0.8798 - val_loss: 0.3505
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9809 - loss: 0.0716 - val_accuracy: 0.8815 - val_loss: 0.3633
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9834 - loss: 0.0621 - val_accuracy: 0.8781 - val_loss: 0.3903
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9862 - loss: 0.0542 - val_accuracy: 0.8781 - val_loss: 0.4052
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9871 - loss: 0.0485 - val_accuracy: 0.8661 - val_loss: 0.4778
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9906 - loss: 0.0404 - val_accuracy: 0.8730 - val_loss: 0.4631
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9933 - loss: 0.0338 - val_accuracy: 0.8699 - val_loss: 0.4937
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9935 - loss: 0.0308 - val_accuracy: 0.8724 - val_loss: 0.5060
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9957 - loss: 0.0242 - val_accuracy: 0.8712 - val_loss: 0.5290
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9953 - loss: 0.0228 - val_accuracy: 0.8687 - val_loss: 0.5602
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9973 - loss: 0.0181 - val_accuracy: 0.8698 - val_loss: 0.5798

# %%
# Much larger: 512-unit layers
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(512, activation="relu"),
    layers.Dense(1, activation="sigmoid"),
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
history_larger = model.fit(
    train_data, train_labels,
    epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7081 - loss: 0.5764 - val_accuracy: 0.8679 - val_loss: 0.3494
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8729 - loss: 0.3106 - val_accuracy: 0.8505 - val_loss: 0.3448
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9037 - loss: 0.2396 - val_accuracy: 0.8878 - val_loss: 0.2714
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9276 - loss: 0.1870 - val_accuracy: 0.8357 - val_loss: 0.4101
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9484 - loss: 0.1387 - val_accuracy: 0.8285 - val_loss: 0.5078
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9616 - loss: 0.1045 - val_accuracy: 0.8845 - val_loss: 0.3450
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9719 - loss: 0.0892 - val_accuracy: 0.8845 - val_loss: 0.3601
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9777 - loss: 0.0732 - val_accuracy: 0.8840 - val_loss: 0.3672
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9810 - loss: 0.0772 - val_accuracy: 0.8754 - val_loss: 0.3523
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9992 - loss: 0.0128 - val_accuracy: 0.8840 - val_loss: 0.4519
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9796 - loss: 0.0801 - val_accuracy: 0.8837 - val_loss: 0.3686
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9999 - loss: 0.0064 - val_accuracy: 0.8844 - val_loss: 0.4773
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9999 - loss: 0.0026 - val_accuracy: 0.8838 - val_loss: 0.5456
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9823 - loss: 0.0985 - val_accuracy: 0.8815 - val_loss: 0.4484
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8835 - val_loss: 0.5138
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8828 - val_loss: 0.5830
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 7.9114e-04 - val_accuracy: 0.8825 - val_loss: 0.6293
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 5.2500e-04 - val_accuracy: 0.8806 - val_loss: 0.6775
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 3.8337e-04 - val_accuracy: 0.8829 - val_loss: 0.6918
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 1.0000 - loss: 2.6237e-04 - val_accuracy: 0.8827 - val_loss: 0.7160

# %%
epochs = range(1, 21)
plt.plot(epochs, history_original.history["val_loss"], "r--",
         label="Baseline (16 units)")
plt.plot(epochs, history_larger.history["val_loss"], "b-",
         label="Larger model (512 units)")
plt.title("Baseline vs. larger model — IMDB validation loss")
plt.xlabel("Epochs")
plt.ylabel("Validation loss")
plt.xticks(epochs)
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## Demo 3 — Dropout fixes it
#
# Same baseline architecture, but with Dropout(0.5) after each hidden layer.
# Compare against the original baseline from Demo 2.

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(16, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid"),
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
history_dropout = model.fit(
    train_data, train_labels,
    epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6181 - loss: 0.6515 - val_accuracy: 0.8471 - val_loss: 0.5649
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7367 - loss: 0.5580 - val_accuracy: 0.8606 - val_loss: 0.4651
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8017 - loss: 0.4726 - val_accuracy: 0.8789 - val_loss: 0.3832
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8462 - loss: 0.4006 - val_accuracy: 0.8779 - val_loss: 0.3344
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8727 - loss: 0.3409 - val_accuracy: 0.8900 - val_loss: 0.2933
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8898 - loss: 0.3008 - val_accuracy: 0.8908 - val_loss: 0.2849
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9073 - loss: 0.2651 - val_accuracy: 0.8916 - val_loss: 0.2750
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9201 - loss: 0.2384 - val_accuracy: 0.8858 - val_loss: 0.2843
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9332 - loss: 0.2112 - val_accuracy: 0.8866 - val_loss: 0.2880
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9374 - loss: 0.1859 - val_accuracy: 0.8905 - val_loss: 0.2976
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9465 - loss: 0.1684 - val_accuracy: 0.8894 - val_loss: 0.3236
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9524 - loss: 0.1521 - val_accuracy: 0.8883 - val_loss: 0.3439
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.1352 - val_accuracy: 0.8896 - val_loss: 0.3440
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9611 - loss: 0.1253 - val_accuracy: 0.8879 - val_loss: 0.3663
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9627 - loss: 0.1165 - val_accuracy: 0.8876 - val_loss: 0.3973
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9652 - loss: 0.1061 - val_accuracy: 0.8869 - val_loss: 0.4221
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9683 - loss: 0.0998 - val_accuracy: 0.8853 - val_loss: 0.4401
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9707 - loss: 0.0867 - val_accuracy: 0.8853 - val_loss: 0.4813
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9725 - loss: 0.0873 - val_accuracy: 0.8862 - val_loss: 0.4720
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9742 - loss: 0.0794 - val_accuracy: 0.8848 - val_loss: 0.5104

# %%
epochs = range(1, 21)
plt.plot(epochs, history_original.history["val_loss"], "r--",
         label="Original (no dropout)")
plt.plot(epochs, history_dropout.history["val_loss"], "b-",
         label="With dropout")
plt.title("Original vs. dropout-regularized model — IMDB validation loss")
plt.xlabel("Epochs")
plt.ylabel("Validation loss")
plt.xticks(epochs)
plt.legend()
plt.show()
