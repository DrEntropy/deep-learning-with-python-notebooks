# %% [markdown]
# Notes from RJL:
# - Using this on my Mac studio, jax and torch were about the same speed.
# - The colab was about 5x faster so i went with that.
# - Using feature extraction withough augmentation was the most bang for the buck: you could run this on a CPU!
# - Using augmentation and fine-tuning was slow and did not significantly improve the results.

# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 44.2 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 65.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.26.0 requires keras-hub==0.26.0, but you have keras-hub 0.28.0 which is incompatible.

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"
#os.environ["KERAS_BACKEND"] = "torch". about the same speed

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## Image classification

# %% [markdown]
# ### Introduction to ConvNets

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)          │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                   │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)      │ (None, 13, 13, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)                 │ (None, 11, 11, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)    │ (None, 5, 5, 128)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)                 │ (None, 3, 3, 256)        │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d          │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense (Dense)                     │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9182 - loss: 0.2615
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9783 - loss: 0.0707
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9854 - loss: 0.0477
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9886 - loss: 0.0364
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9909 - loss: 0.0294

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9908 - loss: 0.0283
# Test accuracy: 0.991

# %% [markdown]
# #### The convolution operation

# %% [markdown]
# ##### Understanding border effects and padding

# %% [markdown]
# ##### Understanding convolution strides

# %% [markdown]
# #### The max-pooling operation

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary(line_length=80)

# %% [markdown]
# ### Training a ConvNet from scratch on a small dataset

# %% [markdown]
# #### The relevance of deep learning for small-data problems

# %% [markdown]
# #### Downloading the data

# %%
# use dotenv
#from dotenv import load_dotenv  
#load_dotenv()  # take environment variables from .env.
# Out:
# True

# %%
import kagglehub
#kagglehub.whoami()

kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
download_path = kagglehub.competition_download("dogs-vs-cats")
# Out:
# Downloading to /root/.cache/kagglehub/competitions/dogs-vs-cats.archive...
# 100%|██████████| 812M/812M [00:20<00:00, 40.6MB/s]
# Extracting files...

# %%
import zipfile

with zipfile.ZipFile(download_path + "/train.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("dogs_vs_cats_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# #### Building your model

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ rescaling (Rescaling)             │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)                 │ (None, 178, 178, 32)     │           896 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)    │ (None, 89, 89, 32)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)                 │ (None, 87, 87, 64)       │        18,496 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)    │ (None, 43, 43, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)                 │ (None, 41, 41, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)    │ (None, 20, 20, 128)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)                 │ (None, 18, 18, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)    │ (None, 9, 9, 256)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)                 │ (None, 7, 7, 512)        │     1,180,160 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_1        │ (None, 512)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_1 (Dense)                   │ (None, 1)                │           513 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 1,569,089 (5.99 MB)
#  Trainable params: 1,569,089 (5.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %% [markdown]
# #### Data preprocessing

# %%
from keras.utils import image_dataset_from_directory
import os, shutil, pathlib
new_base_dir = pathlib.Path("dogs_vs_cats_small")
batch_size = 64
image_size = (180, 180)
train_dataset = image_dataset_from_directory(
    new_base_dir / "train", image_size=image_size, batch_size=batch_size
)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation", image_size=image_size, batch_size=batch_size
)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test", image_size=image_size, batch_size=batch_size
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# ##### Understanding TensorFlow Dataset objects

# %%
import numpy as np
import tensorflow as tf

random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break

# %%
reshaped_dataset = dataset.map(
    lambda x: tf.reshape(x, (4, 4)),
    num_parallel_calls=8)
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break

# %% [markdown]
# ##### Fitting the model

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (64, 180, 180, 3)
# labels batch shape: (64,)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 366ms/step - accuracy: 0.5315 - loss: 0.6917 - val_accuracy: 0.5000 - val_loss: 0.6956
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.5020 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6921
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.5590 - loss: 0.6852 - val_accuracy: 0.6260 - val_loss: 0.6742
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - accuracy: 0.6010 - loss: 0.6661 - val_accuracy: 0.6330 - val_loss: 0.6379
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.6420 - loss: 0.6427 - val_accuracy: 0.6700 - val_loss: 0.6235
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.5615 - loss: 0.6886 - val_accuracy: 0.6370 - val_loss: 0.6547
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.6525 - loss: 0.6335 - val_accuracy: 0.5940 - val_loss: 0.6419
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.6475 - loss: 0.6226 - val_accuracy: 0.7000 - val_loss: 0.5850
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.7045 - loss: 0.5826 - val_accuracy: 0.6660 - val_loss: 0.6001
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.6820 - loss: 0.5963 - val_accuracy: 0.6920 - val_loss: 0.6069
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.7140 - loss: 0.5744 - val_accuracy: 0.6850 - val_loss: 0.5961
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.7105 - loss: 0.5721 - val_accuracy: 0.6900 - val_loss: 0.5830
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.7305 - loss: 0.5500 - val_accuracy: 0.7250 - val_loss: 0.5527
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.7330 - loss: 0.5316 - val_accuracy: 0.7290 - val_loss: 0.5395
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.7345 - loss: 0.5347 - val_accuracy: 0.7390 - val_loss: 0.5345
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.7450 - loss: 0.5258 - val_accuracy: 0.7280 - val_loss: 0.5411
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.7585 - loss: 0.4987 - val_accuracy: 0.7260 - val_loss: 0.5984
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.7805 - loss: 0.4769 - val_accuracy: 0.7560 - val_loss: 0.5073
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.8110 - loss: 0.4299 - val_accuracy: 0.7580 - val_loss: 0.4960
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.7995 - loss: 0.4420 - val_accuracy: 0.7520 - val_loss: 0.5007
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.8355 - loss: 0.3842 - val_accuracy: 0.7750 - val_loss: 0.5033
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.8465 - loss: 0.3519 - val_accuracy: 0.7740 - val_loss: 0.4983
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.8345 - loss: 0.3791 - val_accuracy: 0.7690 - val_loss: 0.5251
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.8585 - loss: 0.3273 - val_accuracy: 0.7550 - val_loss: 0.6088
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.8475 - loss: 0.3219 - val_accuracy: 0.7900 - val_loss: 0.5169
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9005 - loss: 0.2385 - val_accuracy: 0.7970 - val_loss: 0.5459
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.8995 - loss: 0.2467 - val_accuracy: 0.7700 - val_loss: 0.5952
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9220 - loss: 0.1953 - val_accuracy: 0.7720 - val_loss: 0.6215
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9210 - loss: 0.1912 - val_accuracy: 0.8050 - val_loss: 0.5434
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9360 - loss: 0.1578 - val_accuracy: 0.7590 - val_loss: 0.7041
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9425 - loss: 0.1450 - val_accuracy: 0.7280 - val_loss: 1.0401
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9240 - loss: 0.1870 - val_accuracy: 0.8130 - val_loss: 0.5786
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9700 - loss: 0.0987 - val_accuracy: 0.7890 - val_loss: 0.7050
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.9625 - loss: 0.0966 - val_accuracy: 0.8180 - val_loss: 0.6463
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.9770 - loss: 0.0659 - val_accuracy: 0.8190 - val_loss: 0.7847
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9770 - loss: 0.0634 - val_accuracy: 0.8210 - val_loss: 0.6659
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9900 - loss: 0.0332 - val_accuracy: 0.8320 - val_loss: 0.7109
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9900 - loss: 0.0338 - val_accuracy: 0.7440 - val_loss: 1.3151
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.9610 - loss: 0.1055 - val_accuracy: 0.8080 - val_loss: 0.6885
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.9910 - loss: 0.0389 - val_accuracy: 0.8240 - val_loss: 0.7622
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9885 - loss: 0.0356 - val_accuracy: 0.8280 - val_loss: 0.7922
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9790 - loss: 0.0542 - val_accuracy: 0.8290 - val_loss: 0.7001
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - accuracy: 0.9915 - loss: 0.0265 - val_accuracy: 0.8310 - val_loss: 0.7690
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9940 - loss: 0.0203 - val_accuracy: 0.8220 - val_loss: 0.8853
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9925 - loss: 0.0257 - val_accuracy: 0.7880 - val_loss: 0.9154
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9940 - loss: 0.0197 - val_accuracy: 0.8320 - val_loss: 0.8040
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9990 - loss: 0.0069 - val_accuracy: 0.8410 - val_loss: 0.8433
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8440 - val_loss: 0.8970
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8450 - val_loss: 0.9152
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8450 - val_loss: 0.9452

# %%
import matplotlib.pyplot as plt

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

plt.plot(epochs, accuracy, "r--", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()

plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.7775 - loss: 0.4935
# Test accuracy: 0.778

# %% [markdown]
# #### Using data augmentation

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
]

def data_augmentation(images, targets):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images, targets

augmented_train_dataset = train_dataset.map(
    data_augmentation, num_parallel_calls=8
)
import tensorflow as tf
augmented_train_dataset = augmented_train_dataset.prefetch(tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(10, 10))
for image_batch, _ in train_dataset.take(1):
    image = image_batch[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image, _ = data_augmentation(image, None)
        augmented_image = keras.ops.convert_to_numpy(augmented_image)
        plt.imshow(augmented_image.astype("uint8"))
        plt.axis("off")

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %% [markdown]
# Ran this on collab T4, took about 30 minutes.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 26s 590ms/step - accuracy: 0.5195 - loss: 0.6975 - val_accuracy: 0.5030 - val_loss: 0.6855
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 435ms/step - accuracy: 0.5680 - loss: 0.6781 - val_accuracy: 0.6180 - val_loss: 0.6556
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 618ms/step - accuracy: 0.5700 - loss: 0.6781 - val_accuracy: 0.5350 - val_loss: 0.6831
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 667ms/step - accuracy: 0.5630 - loss: 0.6702 - val_accuracy: 0.5390 - val_loss: 0.6822
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 431ms/step - accuracy: 0.5705 - loss: 0.6651 - val_accuracy: 0.6000 - val_loss: 0.6465
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 433ms/step - accuracy: 0.6155 - loss: 0.6502 - val_accuracy: 0.6270 - val_loss: 0.6373
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - accuracy: 0.6450 - loss: 0.6382 - val_accuracy: 0.6470 - val_loss: 0.6081
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 411ms/step - accuracy: 0.6510 - loss: 0.6255 - val_accuracy: 0.6710 - val_loss: 0.6109
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 433ms/step - accuracy: 0.6745 - loss: 0.6127 - val_accuracy: 0.5630 - val_loss: 0.7274
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 718ms/step - accuracy: 0.6500 - loss: 0.6222 - val_accuracy: 0.6930 - val_loss: 0.5986
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 427ms/step - accuracy: 0.6840 - loss: 0.6012 - val_accuracy: 0.6910 - val_loss: 0.5864
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 441ms/step - accuracy: 0.6865 - loss: 0.5962 - val_accuracy: 0.6990 - val_loss: 0.5652
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 433ms/step - accuracy: 0.6835 - loss: 0.5902 - val_accuracy: 0.6800 - val_loss: 0.6039
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.7175 - loss: 0.5744 - val_accuracy: 0.7040 - val_loss: 0.5858
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 636ms/step - accuracy: 0.6750 - loss: 0.5875 - val_accuracy: 0.7070 - val_loss: 0.5612
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 419ms/step - accuracy: 0.7130 - loss: 0.5675 - val_accuracy: 0.7130 - val_loss: 0.5594
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 395ms/step - accuracy: 0.7250 - loss: 0.5510 - val_accuracy: 0.7150 - val_loss: 0.5712
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.7205 - loss: 0.5513 - val_accuracy: 0.6990 - val_loss: 0.5621
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 409ms/step - accuracy: 0.7220 - loss: 0.5418 - val_accuracy: 0.7160 - val_loss: 0.5598
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 413ms/step - accuracy: 0.7290 - loss: 0.5444 - val_accuracy: 0.7150 - val_loss: 0.5479
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.7375 - loss: 0.5276 - val_accuracy: 0.7410 - val_loss: 0.5289
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.7455 - loss: 0.5326 - val_accuracy: 0.6930 - val_loss: 0.5719
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 398ms/step - accuracy: 0.7305 - loss: 0.5449 - val_accuracy: 0.7360 - val_loss: 0.5330
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - accuracy: 0.7560 - loss: 0.5229 - val_accuracy: 0.7510 - val_loss: 0.5126
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 665ms/step - accuracy: 0.7515 - loss: 0.5020 - val_accuracy: 0.7280 - val_loss: 0.5170
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 650ms/step - accuracy: 0.7640 - loss: 0.5012 - val_accuracy: 0.7510 - val_loss: 0.4958
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.7720 - loss: 0.4927 - val_accuracy: 0.7370 - val_loss: 0.5362
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 644ms/step - accuracy: 0.7680 - loss: 0.4933 - val_accuracy: 0.7430 - val_loss: 0.5062
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 413ms/step - accuracy: 0.7810 - loss: 0.4804 - val_accuracy: 0.7520 - val_loss: 0.4885
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 434ms/step - accuracy: 0.7910 - loss: 0.4516 - val_accuracy: 0.7730 - val_loss: 0.4644
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 422ms/step - accuracy: 0.7895 - loss: 0.4513 - val_accuracy: 0.7680 - val_loss: 0.4824
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 419ms/step - accuracy: 0.7920 - loss: 0.4532 - val_accuracy: 0.7550 - val_loss: 0.4904
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 660ms/step - accuracy: 0.8145 - loss: 0.4229 - val_accuracy: 0.7840 - val_loss: 0.4584
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 662ms/step - accuracy: 0.8065 - loss: 0.4222 - val_accuracy: 0.7720 - val_loss: 0.4881
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.8110 - loss: 0.4104 - val_accuracy: 0.7890 - val_loss: 0.4319
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 658ms/step - accuracy: 0.8150 - loss: 0.4047 - val_accuracy: 0.7570 - val_loss: 0.5308
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.8355 - loss: 0.3720 - val_accuracy: 0.8060 - val_loss: 0.4406
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 408ms/step - accuracy: 0.8390 - loss: 0.3656 - val_accuracy: 0.7850 - val_loss: 0.4705
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.8270 - loss: 0.3700 - val_accuracy: 0.7570 - val_loss: 0.6160
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 407ms/step - accuracy: 0.8400 - loss: 0.3747 - val_accuracy: 0.7690 - val_loss: 0.5785
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 423ms/step - accuracy: 0.8210 - loss: 0.4075 - val_accuracy: 0.7990 - val_loss: 0.4829
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 658ms/step - accuracy: 0.8335 - loss: 0.3687 - val_accuracy: 0.7790 - val_loss: 0.5722
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 651ms/step - accuracy: 0.8390 - loss: 0.3609 - val_accuracy: 0.8080 - val_loss: 0.4022
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.8535 - loss: 0.3389 - val_accuracy: 0.7980 - val_loss: 0.4630
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 662ms/step - accuracy: 0.8445 - loss: 0.3457 - val_accuracy: 0.8110 - val_loss: 0.4018
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 674ms/step - accuracy: 0.8570 - loss: 0.3251 - val_accuracy: 0.8180 - val_loss: 0.4397
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 689ms/step - accuracy: 0.8485 - loss: 0.3342 - val_accuracy: 0.8200 - val_loss: 0.4131
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 425ms/step - accuracy: 0.8585 - loss: 0.3159 - val_accuracy: 0.8230 - val_loss: 0.4416
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 422ms/step - accuracy: 0.8680 - loss: 0.3070 - val_accuracy: 0.8040 - val_loss: 0.4179
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 424ms/step - accuracy: 0.8630 - loss: 0.3139 - val_accuracy: 0.8350 - val_loss: 0.4063
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 666ms/step - accuracy: 0.8585 - loss: 0.3024 - val_accuracy: 0.7890 - val_loss: 0.5836
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 652ms/step - accuracy: 0.8640 - loss: 0.3057 - val_accuracy: 0.8300 - val_loss: 0.3973
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 673ms/step - accuracy: 0.8720 - loss: 0.2998 - val_accuracy: 0.8330 - val_loss: 0.4096
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 431ms/step - accuracy: 0.8810 - loss: 0.2756 - val_accuracy: 0.8230 - val_loss: 0.3782
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 653ms/step - accuracy: 0.8885 - loss: 0.2581 - val_accuracy: 0.8220 - val_loss: 0.4836
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 409ms/step - accuracy: 0.8850 - loss: 0.2710 - val_accuracy: 0.8380 - val_loss: 0.4057
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 418ms/step - accuracy: 0.8930 - loss: 0.2443 - val_accuracy: 0.7910 - val_loss: 0.8215
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 436ms/step - accuracy: 0.8920 - loss: 0.2602 - val_accuracy: 0.8270 - val_loss: 0.5008
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 673ms/step - accuracy: 0.9090 - loss: 0.2508 - val_accuracy: 0.8460 - val_loss: 0.3773
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 417ms/step - accuracy: 0.8930 - loss: 0.2347 - val_accuracy: 0.8410 - val_loss: 0.3957
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 622ms/step - accuracy: 0.9070 - loss: 0.2283 - val_accuracy: 0.8110 - val_loss: 0.5025
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 423ms/step - accuracy: 0.8930 - loss: 0.2538 - val_accuracy: 0.8350 - val_loss: 0.4332
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 619ms/step - accuracy: 0.9090 - loss: 0.2157 - val_accuracy: 0.8390 - val_loss: 0.4389
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 425ms/step - accuracy: 0.9120 - loss: 0.2247 - val_accuracy: 0.8340 - val_loss: 0.4046
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 398ms/step - accuracy: 0.9025 - loss: 0.2408 - val_accuracy: 0.8280 - val_loss: 0.4059
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - accuracy: 0.8970 - loss: 0.2358 - val_accuracy: 0.8440 - val_loss: 0.3954
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 649ms/step - accuracy: 0.9085 - loss: 0.2031 - val_accuracy: 0.8250 - val_loss: 0.5795
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 676ms/step - accuracy: 0.9045 - loss: 0.2125 - val_accuracy: 0.8290 - val_loss: 0.5175
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 436ms/step - accuracy: 0.9105 - loss: 0.2198 - val_accuracy: 0.8420 - val_loss: 0.4212
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - accuracy: 0.9135 - loss: 0.2121 - val_accuracy: 0.8600 - val_loss: 0.3890
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 422ms/step - accuracy: 0.9095 - loss: 0.2189 - val_accuracy: 0.8350 - val_loss: 0.4262
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 431ms/step - accuracy: 0.9135 - loss: 0.2054 - val_accuracy: 0.8280 - val_loss: 0.4459
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 652ms/step - accuracy: 0.9155 - loss: 0.2124 - val_accuracy: 0.8630 - val_loss: 0.3878
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 642ms/step - accuracy: 0.9270 - loss: 0.1918 - val_accuracy: 0.8140 - val_loss: 0.6811
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 661ms/step - accuracy: 0.9190 - loss: 0.1960 - val_accuracy: 0.8550 - val_loss: 0.4575
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 429ms/step - accuracy: 0.9190 - loss: 0.1932 - val_accuracy: 0.8430 - val_loss: 0.4631
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.9390 - loss: 0.1579 - val_accuracy: 0.8440 - val_loss: 0.4424
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 420ms/step - accuracy: 0.9245 - loss: 0.1737 - val_accuracy: 0.7920 - val_loss: 0.7740
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 651ms/step - accuracy: 0.9190 - loss: 0.1787 - val_accuracy: 0.8670 - val_loss: 0.4305
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.9360 - loss: 0.1535 - val_accuracy: 0.8640 - val_loss: 0.4337
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 393ms/step - accuracy: 0.9350 - loss: 0.1611 - val_accuracy: 0.8140 - val_loss: 0.5729
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 635ms/step - accuracy: 0.9340 - loss: 0.1634 - val_accuracy: 0.7980 - val_loss: 0.7531
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.9385 - loss: 0.1506 - val_accuracy: 0.8490 - val_loss: 0.4605
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 716ms/step - accuracy: 0.9455 - loss: 0.1336 - val_accuracy: 0.8660 - val_loss: 0.4584
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - accuracy: 0.9350 - loss: 0.1438 - val_accuracy: 0.8420 - val_loss: 0.4960
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 403ms/step - accuracy: 0.9305 - loss: 0.1664 - val_accuracy: 0.8590 - val_loss: 0.4550
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 434ms/step - accuracy: 0.9440 - loss: 0.1493 - val_accuracy: 0.8530 - val_loss: 0.4936
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 426ms/step - accuracy: 0.9450 - loss: 0.1495 - val_accuracy: 0.8680 - val_loss: 0.4274
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 684ms/step - accuracy: 0.9360 - loss: 0.1456 - val_accuracy: 0.8190 - val_loss: 0.5899
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 659ms/step - accuracy: 0.9355 - loss: 0.1576 - val_accuracy: 0.8690 - val_loss: 0.4099
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 625ms/step - accuracy: 0.9395 - loss: 0.1469 - val_accuracy: 0.8450 - val_loss: 0.4407
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 420ms/step - accuracy: 0.9395 - loss: 0.1590 - val_accuracy: 0.8490 - val_loss: 0.5161
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 667ms/step - accuracy: 0.9205 - loss: 0.1896 - val_accuracy: 0.8630 - val_loss: 0.4005
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 659ms/step - accuracy: 0.9500 - loss: 0.1295 - val_accuracy: 0.8510 - val_loss: 0.5637
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 651ms/step - accuracy: 0.9515 - loss: 0.1249 - val_accuracy: 0.8560 - val_loss: 0.5144
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 395ms/step - accuracy: 0.9570 - loss: 0.1145 - val_accuracy: 0.8630 - val_loss: 0.4924
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 630ms/step - accuracy: 0.9530 - loss: 0.1156 - val_accuracy: 0.8660 - val_loss: 0.4600
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 672ms/step - accuracy: 0.9505 - loss: 0.1277 - val_accuracy: 0.8270 - val_loss: 0.6923
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 417ms/step - accuracy: 0.9600 - loss: 0.1155 - val_accuracy: 0.8460 - val_loss: 0.5499
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 427ms/step - accuracy: 0.9495 - loss: 0.1265 - val_accuracy: 0.8620 - val_loss: 0.4418

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.8370 - loss: 0.4222
# Test accuracy: 0.837

# %% [markdown]
# ### Using a pretrained model

# %% [markdown]
# #### Feature extraction with a pretrained model

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset("xception_41_imagenet")
# Out:
# Downloading to /root/.cache/kagglehub/models/keras/xception/keras/xception_41_imagenet/2/config.json...
# 100%|██████████| 1.79k/1.79k [00:00<00:00, 6.35MB/s]
# Downloading to /root/.cache/kagglehub/models/keras/xception/keras/xception_41_imagenet/2/model.weights.h5...
# 100%|██████████| 79.9M/79.9M [00:00<00:00, 99.7MB/s]

# %%
preprocessor = keras_hub.layers.ImageConverter.from_preset(
    "xception_41_imagenet",
    image_size=(180, 180),
)
# Out:
# Downloading to /root/.cache/kagglehub/models/keras/xception/keras/xception_41_imagenet/2/image_converter.json...
# 100%|██████████| 762/762 [00:00<00:00, 2.98MB/s]

# %% [markdown]
# ##### Fast feature extraction without data augmentation

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = preprocessor(images)
        features = conv_base.predict(preprocessed_images, verbose=0)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)

# %%
train_features.shape
# Out:
# (2000, 6, 6, 2048)

# %%
inputs = keras.Input(shape=(6, 6, 2048))
x = layers.GlobalAveragePooling2D()(inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_features,
    train_labels,
    epochs=10,
    validation_data=(val_features, val_labels),
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9635 - loss: 0.1019 - val_accuracy: 0.9810 - val_loss: 0.0511
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9910 - loss: 0.0268 - val_accuracy: 0.9830 - val_loss: 0.0544
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9950 - loss: 0.0166 - val_accuracy: 0.9830 - val_loss: 0.0484
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9965 - loss: 0.0095 - val_accuracy: 0.9870 - val_loss: 0.0494
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9970 - loss: 0.0095 - val_accuracy: 0.9810 - val_loss: 0.0701
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9990 - loss: 0.0043 - val_accuracy: 0.9860 - val_loss: 0.0600
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9820 - val_loss: 0.0686
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9985 - loss: 0.0042 - val_accuracy: 0.9840 - val_loss: 0.0637
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9970 - loss: 0.0081 - val_accuracy: 0.9820 - val_loss: 0.0651
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9860 - val_loss: 0.0643

# %%
import matplotlib.pyplot as plt

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9845 - loss: 0.0475
# Test accuracy: 0.985

# %% [markdown]
# ##### Feature extraction together with data augmentation

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset(
    "xception_41_imagenet",
    trainable=False,
)

# %%
conv_base.trainable = True
len(conv_base.trainable_weights)

# %%
conv_base.trainable = False
len(conv_base.trainable_weights)

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = preprocessor(inputs)
x = conv_base(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.9025 - loss: 0.2358 - val_accuracy: 0.9290 - val_loss: 1.0499
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 727ms/step - accuracy: 0.9290 - loss: 0.1935 - val_accuracy: 0.7560 - val_loss: 3.4168
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 686ms/step - accuracy: 0.9595 - loss: 0.1243 - val_accuracy: 0.5860 - val_loss: 5.7459
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 903ms/step - accuracy: 0.9665 - loss: 0.1099 - val_accuracy: 0.9290 - val_loss: 0.3530
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 694ms/step - accuracy: 0.9645 - loss: 0.1110 - val_accuracy: 0.9340 - val_loss: 0.5087
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 759ms/step - accuracy: 0.9700 - loss: 0.0794 - val_accuracy: 0.8250 - val_loss: 1.9676
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 892ms/step - accuracy: 0.9695 - loss: 0.0742 - val_accuracy: 0.9540 - val_loss: 0.2248
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 689ms/step - accuracy: 0.9820 - loss: 0.0584 - val_accuracy: 0.9490 - val_loss: 0.3006
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 736ms/step - accuracy: 0.9800 - loss: 0.0578 - val_accuracy: 0.9450 - val_loss: 0.3035
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 905ms/step - accuracy: 0.9750 - loss: 0.0790 - val_accuracy: 0.9660 - val_loss: 0.1489
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 690ms/step - accuracy: 0.9805 - loss: 0.0638 - val_accuracy: 0.9580 - val_loss: 0.1682
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 738ms/step - accuracy: 0.9870 - loss: 0.0418 - val_accuracy: 0.9410 - val_loss: 0.2843
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 719ms/step - accuracy: 0.9830 - loss: 0.0477 - val_accuracy: 0.9090 - val_loss: 0.3611
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 704ms/step - accuracy: 0.9825 - loss: 0.0439 - val_accuracy: 0.9580 - val_loss: 0.1689
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 708ms/step - accuracy: 0.9690 - loss: 0.1034 - val_accuracy: 0.6920 - val_loss: 3.6865
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 697ms/step - accuracy: 0.9785 - loss: 0.0594 - val_accuracy: 0.8690 - val_loss: 0.7770
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 731ms/step - accuracy: 0.9815 - loss: 0.0589 - val_accuracy: 0.8730 - val_loss: 0.4619
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 693ms/step - accuracy: 0.9865 - loss: 0.0339 - val_accuracy: 0.8950 - val_loss: 0.4942
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 694ms/step - accuracy: 0.9840 - loss: 0.0453 - val_accuracy: 0.9410 - val_loss: 0.3196
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 708ms/step - accuracy: 0.9915 - loss: 0.0280 - val_accuracy: 0.9560 - val_loss: 0.1945
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 847ms/step - accuracy: 0.9830 - loss: 0.0485 - val_accuracy: 0.9530 - val_loss: 0.1291
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 694ms/step - accuracy: 0.9920 - loss: 0.0267 - val_accuracy: 0.9370 - val_loss: 0.2444
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 26s 772ms/step - accuracy: 0.9930 - loss: 0.0228 - val_accuracy: 0.9650 - val_loss: 0.1288
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 711ms/step - accuracy: 0.9930 - loss: 0.0171 - val_accuracy: 0.9180 - val_loss: 0.3641
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 691ms/step - accuracy: 0.9925 - loss: 0.0216 - val_accuracy: 0.9490 - val_loss: 0.1943
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 689ms/step - accuracy: 0.9925 - loss: 0.0269 - val_accuracy: 0.9390 - val_loss: 0.1928
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 851ms/step - accuracy: 0.9965 - loss: 0.0107 - val_accuracy: 0.9630 - val_loss: 0.1206
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 692ms/step - accuracy: 0.9930 - loss: 0.0280 - val_accuracy: 0.9110 - val_loss: 0.3022
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 699ms/step - accuracy: 0.9895 - loss: 0.0283 - val_accuracy: 0.9250 - val_loss: 0.1782
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 688ms/step - accuracy: 0.9775 - loss: 0.0601 - val_accuracy: 0.9160 - val_loss: 0.3465

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 232ms/step - accuracy: 0.9715 - loss: 0.1240
# Test accuracy: 0.972

# %% [markdown]
# Use the best model

# %%
model= test_model

# %%
# set the xception layer to be trainable
backbone = model.get_layer("xception_backbone")
backbone.trainable = True

# %% [markdown]
# #### Fine-tuning a pretrained model

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=1,#30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.9955 - loss: 0.0229 - val_accuracy: 0.9640 - val_loss: 0.1087

# %%
history2 = model.fit(
    augmented_train_dataset,
    epochs=10,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9940 - loss: 0.0104 - val_accuracy: 0.9680 - val_loss: 0.1064
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 711ms/step - accuracy: 0.9960 - loss: 0.0112 - val_accuracy: 0.9660 - val_loss: 0.1075
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 712ms/step - accuracy: 0.9980 - loss: 0.0058 - val_accuracy: 0.9660 - val_loss: 0.1113
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 710ms/step - accuracy: 0.9960 - loss: 0.0082 - val_accuracy: 0.9660 - val_loss: 0.1099
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 684ms/step - accuracy: 0.9980 - loss: 0.0053 - val_accuracy: 0.9670 - val_loss: 0.1081
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 694ms/step - accuracy: 0.9970 - loss: 0.0122 - val_accuracy: 0.9670 - val_loss: 0.1077
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 690ms/step - accuracy: 0.9970 - loss: 0.0080 - val_accuracy: 0.9680 - val_loss: 0.1090
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 691ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9690 - val_loss: 0.1097
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 704ms/step - accuracy: 0.9985 - loss: 0.0032 - val_accuracy: 0.9690 - val_loss: 0.1103
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 689ms/step - accuracy: 0.9985 - loss: 0.0066 - val_accuracy: 0.9680 - val_loss: 0.1091

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 305ms/step - accuracy: 0.9770 - loss: 0.1001
# Test accuracy: 0.977
